# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Get the absolute path to the parent directory of the notebook
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../../../../../'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from modules.competitions.Osmosis.v3.osmosis_selector_v3 import OsmosisAlphaSelectorV3

# %%
selector = OsmosisAlphaSelectorV3()
# Out:
# 2026-05-12 19:35:57 - OsmosisAlphaSelectorV3 - 登录成功, 用户ID: ZM10537
# 2026-05-12 19:35:57 - OsmosisAlphaSelectorV3 - 获取数据成功, 571 个 alpha , 266 个 ppac
# 2026-05-12 19:35:59 - OsmosisAlphaSelectorV3 - OsmosisAlphaSelectorV3 init: blacklist=0 items, maxtrade_map=201 items, cache_dir=/home/worldquant/wqb/Code2.0/modules/competitions/Osmosis/v3/data/selector_cache

# %%
from datetime import datetime
selector.select(region="USA", start_date=datetime(2025, 4, 19), fetch_yearly_stats=False, use_cache=False)
# Out:
# ...
# 100%|██████████| 96/96 [00:00<00:00, 166316.89it/s]
# 2026-05-12 19:51:58 - OsmosisAlphaSelectorV3 - fetch_candidates: 最终返回 141 个 Alpha
# 100%|██████████| 22/22 [00:00<00:00, 123527.03it/s]
# 2026-05-12 19:51:59 - OsmosisAlphaSelectorV3 - fetch_candidates: 最终返回 22 个 Alpha
# 2026-05-12 19:51:59 - OsmosisAlphaSelectorV3 - fetch_candidates 后: REGULAR=141, SUPER=22, 总计=163
# 2026-05-12 19:51:59 - OsmosisAlphaSelectorV3 - Layer 1 [HardFilter] (标准): 163 -> 100
# 2026-05-12 19:51:59 - OsmosisAlphaSelectorV3 - Layer 1 [HardFilter] 后: REGULAR=78, SUPER=22, 总计=100
# 2026-05-12 19:52:00 - OsmosisAlphaSelectorV3 - PnL correlation 矩阵: (100, 100)
# 2026-05-12 19:52:00 - OsmosisAlphaSelectorV3 - 评分计算完成: stability=0.500, os_is=0.482, quality=0.602
# 2026-05-12 19:52:00 - OsmosisAlphaSelectorV3 - Layer 2 [Investability]: 1 个 Alpha 衰减严重(≥60%)，已在 quality_score 中大幅降权，建议人工复核: ['kqR7jKdz']
# ...
